# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("./dataset/train.csv")

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ##### Linear Regression with Libraries

# %%
data=df
# Y = np.array(data["SalePrice"].values)
# X = np.array(data["LotArea"].values).reshape(-1,1)
Y = [2,5,6,9,12,13,14,17]
X = np.array([1,2,3,4,5,6,7,8]).reshape(-1,1)
plt.scatter(X,Y)

model = LinearRegression()
model.fit(X,Y)
nY=model.predict(X)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()

# %% [markdown]
# ##### Linear Regresssion without library

# %%
# data=df
Y = [2,5,6,9,12,13,14,17]
X = np.array([1,2,3,4,5,6,7,8]).reshape(-1,1)
B = np.ones((len(X),1))
# X = np.append(x,X,axis=1).astype('int8')
X = np.append(x,X,axis=1)
B = np.ones((X.shape[1]))
a = 0.01

def h(X,B):
    return np.sum(B*X,axis=1)

def cost(B,Ypr,Y):
    print(sum(pow(Ypr-Y,2))/len(X))

def gd(a,B,Y,Ypr):
    for k in range(10):
        n=len(X)
        B[0]-=a*-2/n*sum(Y-Ypr)
        for i in range(1,len(B)):
            B[i]-=a*-2/n*sum(X[:,1][i]*(Y-Ypr))
#         print(B)
        print(cost(B,Ypr,Y))
        Ypr=h(X,B)
        plt.scatter(X[:,1],Y)
        plt.plot(X[:,1],Ypr)
        plt.show()
    return Ypr

Ypr=h(X,B)
cost(B,Ypr,Y)
Ypr=gd(a,B,Y,Ypr)
plt.scatter(X[:,1],Y)
plt.plot(X[:,1],Ypr)
plt.show()
# Out:
# 24.5
# 24.5
# None
# 16.236725
# None
# 10.884988999999997
# None
# 7.40928596
# None
# 5.144362414399996
# None
# 3.6624324652160003
# None
# 2.68809419373824
# None
# 2.043795216792472
# None
# 1.6148658849871815
# None
# 1.3270887233837976
# None

# %%
# Y = np.array(data["SalePrice"].values)
# X = np.array(data["LotArea"].values).reshape(-1,1)
X = np.arange(10).reshape(-1,1)
Y = X*X*X

poly = PolynomialFeatures(3)
nX = poly.fit_transform(X)

model = LinearRegression()
model.fit(nX,Y)
nY=model.predict(nX)
plt.scatter(X,Y)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()

# %%
data=df
# print(data["YearBuilt"])
Y = np.array(data["SalePrice"].values).reshape(-1,1)
X = np.array(data[["LotArea","YearBuilt","OverallQual"]].values).reshape(-1,3)
# print(X)
plt.scatter(X[:,0],Y)
plt.scatter(X[:,1],Y)
plt.scatter(X[:,2],Y)

model = LinearRegression()
model.fit(X,Y)
nY=model.predict(X)
print(model.coef_)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()
# Out:
# [[1.49385142e+00 3.08602768e+02 4.04379101e+04]]
