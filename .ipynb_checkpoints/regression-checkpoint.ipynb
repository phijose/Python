# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("./dataset/train.csv")

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ##### Linear Regression with Libraries

# %%
data=df
Y = np.array(data["SalePrice"].values)
X = np.array(data["LotArea"].values).reshape(-1,1)
plt.scatter(X,Y)

model = LinearRegression()
model.fit(X,Y)
nY=model.predict(X)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()

# %% [markdown]
# ##### Linear Regresssion without library

# %%
data=df
Y = np.array(data["SalePrice"].values)
X = np.array(data["LotArea"].values).reshape(-1,1)

def linearReg(X,Y,a=None,b=None):
    X=X.reshape(-1)
    if(a==None and b==None):
        zX2=sum(X*X)
        zY=sum(Y)
        zX=sum(X)
        zXY=sum(X*Y)
        n=len(X)
        print(zX,zY,zXY,zX2,sep="\n")
        a=((zY*zX2)-(zX*zXY))/((n*zX2)-(zX*zX))
        b=((n*zXY)-(zX*zY))/((n*zX2)-(zX*zX))
    nY = a + X*b
    return (nY,a,b)

# model = LinearRegression()
# print(Y)
# print(linearReg(X,Y))
# model.fit(X,Y)
# print(model.predict(X))
lrnRte = 0.0000000001
epoche=2
# err = mean_squared_error(Y,nY,squared=True)
# for i in range(epoche):
#     model.fit(X,Y)
#     nY=model.predict(X)
#     theta1 = model.coef_
#     theta0 = model.intercept_
#     model.intercept_ = theta0 - sum((nY-Y)*(nY-Y))*theta0*(1/len(Y))*lrnRte
#     model.coef_ = theta1 - sum((nY-Y)*(nY-Y))*theta1*(1/len(Y))*lrnRte
#     print(theta0,theta1)
# nY,a,b=linearReg(X,Y)
nY=0
a=b=.1
print(a,b)
for i in range(epoche):
#     a += sum((nY-Y)*(nY-Y))*a*(1/len(Y))*lrnRte
    a -= sum((nY-Y)*(nY-Y))*a*(1/len(Y))*lrnRte
#     b += sum((nY-Y)*(nY-Y))*b*(1/len(Y))*lrnRte
    nY,a,b=linearReg(X,Y,a,b)
    print(a,b)
plt.scatter(X,Y)
print(nY)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()
# Out:
# 0.1 0.1
# 0.49039267707765766 0.49039267707765766
# 2.3057492884783306 2.3057492884783306
# [19485.88723693 22137.49891868 25941.98524467 ... 20850.89081571
#  22407.27158543 22914.5364289 ]

# %%
# Y = np.array(data["SalePrice"].values)
# X = np.array(data["LotArea"].values).reshape(-1,1)
X = np.arange(10).reshape(-1,1)
Y = X*X*X

poly = PolynomialFeatures(3)
nX = poly.fit_transform(X)

model = LinearRegression()
model.fit(nX,Y)
nY=model.predict(nX)
plt.scatter(X,Y)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()

# %%
data=df
# print(data["YearBuilt"])
Y = np.array(data["SalePrice"].values).reshape(-1,1)
X = np.array(data[["LotArea","YearBuilt","OverallQual"]].values).reshape(-1,3)
# print(X)
plt.scatter(X[:,0],Y)
plt.scatter(X[:,1],Y)
plt.scatter(X[:,2],Y)

model = LinearRegression()
model.fit(X,Y)
nY=model.predict(X)
print(model.coef_)
plt.plot(X,nY,c="red")
plt.title("Linear Regression")
plt.show()
# Out:
# [[1.49385142e+00 3.08602768e+02 4.04379101e+04]]
